# %% [markdown]
# <a href="https://colab.research.google.com/github/BVISHNU78/ATS-APPLICATION-TRACKING-SYSTEM-/blob/main/ATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import docx2txt

# %%
pip install docx2txt
# Out:
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=c6ec2bc9fc5721b5fbd13c6077f7b0efe2e5671b6fe781542805868cf3eeac26
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8

# %%
#from google.colab import files
#uploaded=files.upload()

# %%
resume=docx2txt.process("/content/latest cv of Waseem.docx")
print(resume)
# Out:
# WASEEM P C
#
# Data Analyst
#
# waseempkl95@gmail.com
#
# 8893704848
#
# 	Calicut	Indian
#
# Y6308254
#
# https://www.linkedin.com/in/waseem-p-c-a07003252Seasoned data analyst with a proven track record of two years in gathering insights from a variety of datasets. capable with Power BI, Python, SQL, and data visualization software. adept in converting complex data into workable business solutions and working cooperatively to solve problems. knowledgeable about natural language processing (NLP), deep learning, and machine learning.
#
#
#
#    PROFESSIONAL  EXPERIENCE
#
#
#
# Project Data Analyst TrueD (Freelancer)
#
# Currently serving as a Project Analyst, overseeing the planning and execution of data-driven projects
#
#
# 12/2023 – present
#
#
#
# Utilize Python for advanced data analysis, including the implementation of machine learning models, to derive meaningful insights and actionable recommendations
#
# Guide and mentor learners in data visualization projects, imparting practical skills in creating effective visualizations Conduct regular data reviews, identifying trends and patterns to enhance project outcomes
#
#
#
# Data Analyst
#
# Worked as data analyst for a client on the study on impact of art therapy on stress levels on children. Used data analytical software like SPSS, Excel, Tableau and Microsoft Word for documentation.
#
# Checked the normality of the data and conducted chi-square for independence and independent sample T- test Used various graphical plots for better interpretability of the data
#
# Mentor
#
# Served as Mentor for '7 days of Hands-on Training Online Workshop on SPSS in research data analysis'
#
#
#
# PROJECTS
#
# Telecom Churn Prediction Project
#
#
# Aligarh,UP, India
#
#
#
#
#
#
#
# Aligarh
#
#
#
# To predict customer churn in a telecom company using various classification models and evaluating their performance. Additionally, applied the SMOTE (Synthetic Minority Over-sampling Technique) technique to address class imbalance.
#
# Employed various classification models, including Logistic Regression,Decision Trees, Random Forest ,Support Vector Machines (SVM) Compared the performance of different models and identified the most suitable one for the task.
#
# Text Authenticity Classifier using Natural Language Processing (NLP)
#
# Gathered a diverse dataset containing examples of both real and fake textual content from various sources and conducted extensive text cleaning, including removal of stopwords, punctuation, and special characters.
#
# Tokenized and stemmed the text to prepare it for feature extraction.
#
# Utilized TF-IDF (Term Frequency-Inverse Document Frequency) to convert text data into numerical features.
#
# Explored NLP model Logistic Regression and evaluated the model using metrics such as accuracy, precision, recall, and F1-score to ensure a balanced assessment of its performance.
#
# Supermarket store branches sales analysis-EDA
#
# Created visually compelling and informative plots, graphs, and visualizations to illustrate trends and patterns within the sales data. Derived actionable insights from the EDA process to better understand sales pattern, ratings, product lines, and behavior of customers .
#
#
#
# MSc Project
#
# A project has done on the topic "Status of primary to higher secondary levels of education in India: A Statistical Study Using R and Python Software on the Data of Gross Enrolment Ratio (GER) and Net Enrolment Rate (NER) of India to Assess the Preparedness for Achieving Some Targets of Sustainable Development Goal (SDG) -- 4"
#
# Bsc Project
#
#
# 2022 – 2023
#
#
#
#
#
#
#
# 2020 – 2021
#
#
#
# Project has done to study the impact of COVID-19 on the physical and mental health of healthcare workers of Kerala from the district of Calicut and Malappuram. The project also intense to provide information on the risk reduction methods adopted by the health care staffs to reduce the spread.
#
#
#
#    SKILLS
#
# 											Data Analysis	R programming	Python	SPSS	Regression	Predictive Modeling	Data Visualization	Statistical Analysis SQL	Power BI		Machine learning	Natural language processing		Deep Learning
#
# EDUCATION
#
#
#
# MSc Statistics
#
# Aligarh Muslim University
#
# BSc Statistics
#
# Farook College,Calicut University
#
#
#
#    CERTIFICATES
#
# Machine Learning with Python - Level 1 from IBM
#
# 7 days of Hands-on Training Online Workshop on SPSS in research data analysis
#
# one day training programme on 'Transform your career with datascience'
#
#
# 2021 – 2023 | Aligarh, India
#
#
#
# 2018 – 2021 | Calicut, India
#
#
#
#
#
#
#
# Data Analysis with python a course on cognitiveclass.ai Powered by IBM Developer Skills Network.
#
# Data Analysis with R and Excel software
#
#
#
# waseempkl95@gmail.com

# %%
job_des=docx2txt.process("/content/job desc.docx")
print(job_des)
# Out:
# Role Description
#
# This is a full-time remote role for a Data Analyst. The Data Analyst will be responsible for analyzing data sets, creating data models, and reporting on findings. They will also be responsible for communicating their findings to other departments and stakeholders within the organization.
#
#
#
# Qualifications
#
# Analytical Skills, Data Analytics, and Statistics
#
# Excellent Communication skills
#
# Data Modeling skills
#
# Bachelor's degree in Mathematics, Statistics, Computer Science, or related field
#
# Experience with SQL and data visualization tools
#
# Attention to detail and ability to work independently

# %%
text=[resume,job_des]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
Count_matrix=cv.fit_transform(text)

# %%
from sklearn.metrics.pairwise  import cosine_similarity
print("\nsimilarity Scores")
print(cosine_similarity(Count_matrix))
# Out:
# similarity Scores
# [[1.         0.57214137]
#  [0.57214137 1.        ]]

# %%
matchpercentage=cosine_similarity(Count_matrix)[0][1]*100
matchpercentage=round(matchpercentage,2)
print("ur resume matches about"+str(matchpercentage)+"% of the job_descrpition")
# Out:
# ur resume matches about57.21% of the job_descrpition
